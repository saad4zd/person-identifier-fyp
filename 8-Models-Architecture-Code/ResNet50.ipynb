# %% [markdown]
# ### Importing Libraries

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.metrics import top_k_categorical_accuracy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Conv2D, BatchNormalization, Input, AveragePooling2D, Dense, Add, Flatten, Activation, MaxPooling2D, ZeroPadding2D
# Out:
# 2024-04-22 12:49:35.718155: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-22 12:49:35.772761: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-22 12:49:36.844159: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/saad-bscs/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ### Constants

# %%
batch_size = 32
num_classes = 124
tf.random.set_seed(42)
img_height, img_width = 128, 128
data_dir = os.path.join(os.getcwd(), "../5-Gait-Energy-Images")

# %% [markdown]
# ### Training Data Augmentation

# %%
train_datagen = ImageDataGenerator(
    shear_range=0.2,
    rescale=1.0 / 255,
    rotation_range=20,
    fill_mode="nearest",
    horizontal_flip=True,
    zoom_range=[0.8, 1.2],
    width_shift_range=0.2,
    validation_split=0.15,
    height_shift_range=0.2,
    channel_shift_range=10,
    brightness_range=[0.8, 1.2],
)

# %% [markdown]
# ### Testing Data Augmentation

# %%
test_datagen = ImageDataGenerator(rescale=1.0 / 255, validation_split=0.15)

# %% [markdown]
# ### Load and split data into training and testing sets

# %%
train_generator = train_datagen.flow_from_directory(
    data_dir,
    seed=42,
    shuffle=True,
    subset="training",
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode="categorical",
    target_size=(img_height, img_width),
)

test_generator = test_datagen.flow_from_directory(
    data_dir,
    seed=42,
    shuffle=False,
    subset="validation",
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode="categorical",
    target_size=(img_height, img_width),
)
# Out:
# Found 11587 images belonging to 124 classes.
# Found 1974 images belonging to 124 classes.

# %% [markdown]
# ### ResNet50 Model

# %%
def identity_block(X, f, filters, stage, block):
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    F1, F2, F3 = filters
    
    X_shortcut = X
        
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
        
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    X = Add()([X_shortcut, X])
    X = Activation('relu')(X)
    return X

def convolutional_block(X, f, filters, stage, block, s = 2):
        
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters
    X_shortcut = X
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)
    X_shortcut = Conv2D(filters = F3, kernel_size = (1, 1), strides = (s,s), padding = 'valid', name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)
    X = Add()([X_shortcut, X])
    X = Activation('relu')(X)
   
    return X

def ResNet50(input_shape, classes):
    X_input = Input(input_shape)
    X = ZeroPadding2D((3, 3))(X_input)
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')
    X = AveragePooling2D(pool_size=(2, 2),name='avg_pool')(X)
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    model = Model(inputs = X_input, outputs = X, name='ResNet50')
    return model

# %% [markdown]
# ### Create the model

# %%
model = ResNet50(input_shape = (128, 128, 1), classes = num_classes)
# Out:
# 2024-04-22 12:49:39.346894: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### Define Top k Accuracy Function

# %%
def top_5_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=5)

# %% [markdown]
# ### Compile the model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',
              metrics=['acc', top_5_accuracy])

# %% [markdown]
# ### Define the Callbacks

# %%
checkpoint = ModelCheckpoint(
    "best_model.h5", monitor='val_acc', save_best_only=True, mode='max')
early_stopping = EarlyStopping(
    monitor='val_acc', patience=30, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(
    monitor='val_acc', factor=0.1, patience=5, min_lr=1e-7)

# %% [markdown]
# ### Train the model

# %%
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=500,
    callbacks=[checkpoint, early_stopping, reduce_lr],
    use_multiprocessing=True)
# Out:
# Epoch 1/500
# 363/363 [==============================] - ETA: 0s - loss: 6.1012 - acc: 0.0098 - top_5_accuracy: 0.0441
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 363/363 [==============================] - 250s 643ms/step - loss: 6.1012 - acc: 0.0098 - top_5_accuracy: 0.0441 - val_loss: 84.4206 - val_acc: 0.0071 - val_top_5_accuracy: 0.0446 - lr: 0.0010
# Epoch 2/500
# 363/363 [==============================] - 231s 633ms/step - loss: 4.7846 - acc: 0.0181 - top_5_accuracy: 0.0857 - val_loss: 5.1508 - val_acc: 0.0284 - val_top_5_accuracy: 0.1327 - lr: 0.0010
# Epoch 3/500
# 363/363 [==============================] - 231s 631ms/step - loss: 4.4793 - acc: 0.0339 - top_5_accuracy: 0.1322 - val_loss: 9.6350 - val_acc: 0.0228 - val_top_5_accuracy: 0.0851 - lr: 0.0010
# Epoch 4/500
# 363/363 [==============================] - 231s 631ms/step - loss: 4.2790 - acc: 0.0500 - top_5_accuracy: 0.1860 - val_loss: 28.0344 - val_acc: 0.0091 - val_top_5_accuracy: 0.0446 - lr: 0.0010
# Epoch 5/500
# 363/363 [==============================] - 233s 636ms/step - loss: 3.9999 - acc: 0.0777 - top_5_accuracy: 0.2598 - val_loss: 6.7449 - val_acc: 0.0299 - val_top_5_accuracy: 0.1175 - lr: 0.0010
# Epoch 6/500
# 363/363 [==============================] - 231s 632ms/step - loss: 3.8113 - acc: 0.0960 - top_5_accuracy: 0.3104 - val_loss: 9.1646 - val_acc: 0.0203 - val_top_5_accuracy: 0.0892 - lr: 0.0010
# Epoch 7/500
# 363/363 [==============================] - 233s 636ms/step - loss: 3.6245 - acc: 0.1225 - top_5_accuracy: 0.3540 - val_loss: 6.9368 - val_acc: 0.0375 - val_top_5_accuracy: 0.1535 - lr: 0.0010
# Epoch 8/500
# 363/363 [==============================] - 231s 631ms/step - loss: 3.5319 - acc: 0.1367 - top_5_accuracy: 0.3799 - val_loss: 4.3332 - val_acc: 0.0800 - val_top_5_accuracy: 0.2680 - lr: 0.0010
# Epoch 9/500
# %% [markdown]
# ### Evaluate model on training set

# %%
train_loss, train_accuracy, top5train = model.evaluate(train_generator)
print(f"Training Loss: {round(train_loss, 2)}")
print(f"Training Accuracy: {round(train_accuracy, 2)}")
print(f"Training Top 5 Accuracy: {round(top5train, 2)}")
# Out:
# 363/363 [==============================] - 69s 190ms/step - loss: 0.1280 - acc: 0.9607 - top_5_accuracy: 0.9976
# Training Loss: 0.13
# Training Accuracy: 0.96
# Training Top 5 Accuracy: 1.0

# %% [markdown]
# ### Evaluate model on testing set

# %%
test_loss, test_accuracy, top5test = model.evaluate(test_generator)
print(f"Testing Loss: {round(test_loss, 2)}")
print(f"Testing Accuracy: {round(test_accuracy, 2)}")
print(f"Testing Top 5 Accuracy: {round(top5test, 2)}")
# Out:
# 62/62 [==============================] - 11s 183ms/step - loss: 0.8007 - acc: 0.8156 - top_5_accuracy: 0.9574
# Testing Loss: 0.8
# Testing Accuracy: 0.82
# Testing Top 5 Accuracy: 0.96

# %% [markdown]
# ### Save the model

# %%
model.save('../10-Trained-Models/ResNet50.h5')

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 134, 134, 1)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1 (Conv2D)              (None, 64, 64, 64)           3200      ['zero_padding2d[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 64, 64, 64)           256       ['conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 64, 64, 64)           0         ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 31, 31, 64)           0         ['activation[0][0]']
#  D)
#
#  res2a_branch2a (Conv2D)     (None, 31, 31, 64)           4160      ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 31, 31, 64)           256       ['res2a_branch2a[0][0]']
#  ization)
#
#  activation_1 (Activation)   (None, 31, 31, 64)           0         ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)     (None, 31, 31, 64)           36928     ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormal  (None, 31, 31, 64)           256       ['res2a_branch2b[0][0]']
#  ization)
#
#  activation_2 (Activation)   (None, 31, 31, 64)           0         ['bn2a_branch2b[0][0]']
#
#  res2a_branch1 (Conv2D)      (None, 31, 31, 256)          16640     ['max_pooling2d[0][0]']
#
#  res2a_branch2c (Conv2D)     (None, 31, 31, 256)          16640     ['activation_2[0][0]']
#
#  bn2a_branch1 (BatchNormali  (None, 31, 31, 256)          1024      ['res2a_branch1[0][0]']
#  zation)
#
#  bn2a_branch2c (BatchNormal  (None, 31, 31, 256)          1024      ['res2a_branch2c[0][0]']
#  ization)
#
#  add (Add)                   (None, 31, 31, 256)          0         ['bn2a_branch1[0][0]',
#                                                                      'bn2a_branch2c[0][0]']
#
#  activation_3 (Activation)   (None, 31, 31, 256)          0         ['add[0][0]']
#
#  res2b_branch2a (Conv2D)     (None, 31, 31, 64)           16448     ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormal  (None, 31, 31, 64)           256       ['res2b_branch2a[0][0]']
#  ization)
#
#  activation_4 (Activation)   (None, 31, 31, 64)           0         ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)     (None, 31, 31, 64)           36928     ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormal  (None, 31, 31, 64)           256       ['res2b_branch2b[0][0]']
#  ization)
#
#  activation_5 (Activation)   (None, 31, 31, 64)           0         ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)     (None, 31, 31, 256)          16640     ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormal  (None, 31, 31, 256)          1024      ['res2b_branch2c[0][0]']
#  ization)
#
#  add_1 (Add)                 (None, 31, 31, 256)          0         ['activation_3[0][0]',
#                                                                      'bn2b_branch2c[0][0]']
#
#  activation_6 (Activation)   (None, 31, 31, 256)          0         ['add_1[0][0]']
#
#  res2c_branch2a (Conv2D)     (None, 31, 31, 64)           16448     ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormal  (None, 31, 31, 64)           256       ['res2c_branch2a[0][0]']
#  ization)
#
#  activation_7 (Activation)   (None, 31, 31, 64)           0         ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)     (None, 31, 31, 64)           36928     ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormal  (None, 31, 31, 64)           256       ['res2c_branch2b[0][0]']
#  ization)
#
#  activation_8 (Activation)   (None, 31, 31, 64)           0         ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)     (None, 31, 31, 256)          16640     ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormal  (None, 31, 31, 256)          1024      ['res2c_branch2c[0][0]']
#  ization)
#
#  add_2 (Add)                 (None, 31, 31, 256)          0         ['activation_6[0][0]',
#                                                                      'bn2c_branch2c[0][0]']
#
#  activation_9 (Activation)   (None, 31, 31, 256)          0         ['add_2[0][0]']
#
#  res3a_branch2a (Conv2D)     (None, 16, 16, 128)          32896     ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormal  (None, 16, 16, 128)          512       ['res3a_branch2a[0][0]']
#  ization)
#
#  activation_10 (Activation)  (None, 16, 16, 128)          0         ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)     (None, 16, 16, 128)          147584    ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormal  (None, 16, 16, 128)          512       ['res3a_branch2b[0][0]']
#  ization)
#
#  activation_11 (Activation)  (None, 16, 16, 128)          0         ['bn3a_branch2b[0][0]']
#
#  res3a_branch1 (Conv2D)      (None, 16, 16, 512)          131584    ['activation_9[0][0]']
#
#  res3a_branch2c (Conv2D)     (None, 16, 16, 512)          66048     ['activation_11[0][0]']
#
#  bn3a_branch1 (BatchNormali  (None, 16, 16, 512)          2048      ['res3a_branch1[0][0]']
#  zation)
#
#  bn3a_branch2c (BatchNormal  (None, 16, 16, 512)          2048      ['res3a_branch2c[0][0]']
#  ization)
#
#  add_3 (Add)                 (None, 16, 16, 512)          0         ['bn3a_branch1[0][0]',
#                                                                      'bn3a_branch2c[0][0]']
#
#  activation_12 (Activation)  (None, 16, 16, 512)          0         ['add_3[0][0]']
#
#  res3b_branch2a (Conv2D)     (None, 16, 16, 128)          65664     ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormal  (None, 16, 16, 128)          512       ['res3b_branch2a[0][0]']
#  ization)
#
#  activation_13 (Activation)  (None, 16, 16, 128)          0         ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)     (None, 16, 16, 128)          147584    ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormal  (None, 16, 16, 128)          512       ['res3b_branch2b[0][0]']
#  ization)
#
#  activation_14 (Activation)  (None, 16, 16, 128)          0         ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)     (None, 16, 16, 512)          66048     ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormal  (None, 16, 16, 512)          2048      ['res3b_branch2c[0][0]']
#  ization)
#
#  add_4 (Add)                 (None, 16, 16, 512)          0         ['activation_12[0][0]',
#                                                                      'bn3b_branch2c[0][0]']
#
#  activation_15 (Activation)  (None, 16, 16, 512)          0         ['add_4[0][0]']
#
#  res3c_branch2a (Conv2D)     (None, 16, 16, 128)          65664     ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormal  (None, 16, 16, 128)          512       ['res3c_branch2a[0][0]']
#  ization)
#
#  activation_16 (Activation)  (None, 16, 16, 128)          0         ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)     (None, 16, 16, 128)          147584    ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormal  (None, 16, 16, 128)          512       ['res3c_branch2b[0][0]']
#  ization)
#
#  activation_17 (Activation)  (None, 16, 16, 128)          0         ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)     (None, 16, 16, 512)          66048     ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormal  (None, 16, 16, 512)          2048      ['res3c_branch2c[0][0]']
#  ization)
#
#  add_5 (Add)                 (None, 16, 16, 512)          0         ['activation_15[0][0]',
#                                                                      'bn3c_branch2c[0][0]']
#
#  activation_18 (Activation)  (None, 16, 16, 512)          0         ['add_5[0][0]']
#
#  res3d_branch2a (Conv2D)     (None, 16, 16, 128)          65664     ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormal  (None, 16, 16, 128)          512       ['res3d_branch2a[0][0]']
#  ization)
#
#  activation_19 (Activation)  (None, 16, 16, 128)          0         ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)     (None, 16, 16, 128)          147584    ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormal  (None, 16, 16, 128)          512       ['res3d_branch2b[0][0]']
#  ization)
#
#  activation_20 (Activation)  (None, 16, 16, 128)          0         ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)     (None, 16, 16, 512)          66048     ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormal  (None, 16, 16, 512)          2048      ['res3d_branch2c[0][0]']
#  ization)
#
#  add_6 (Add)                 (None, 16, 16, 512)          0         ['activation_18[0][0]',
#                                                                      'bn3d_branch2c[0][0]']
#
#  activation_21 (Activation)  (None, 16, 16, 512)          0         ['add_6[0][0]']
#
#  res4a_branch2a (Conv2D)     (None, 8, 8, 256)            131328    ['activation_21[0][0]']
#
#  bn4a_branch2a (BatchNormal  (None, 8, 8, 256)            1024      ['res4a_branch2a[0][0]']
#  ization)
#
#  activation_22 (Activation)  (None, 8, 8, 256)            0         ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)     (None, 8, 8, 256)            590080    ['activation_22[0][0]']
#
#  bn4a_branch2b (BatchNormal  (None, 8, 8, 256)            1024      ['res4a_branch2b[0][0]']
#  ization)
#
#  activation_23 (Activation)  (None, 8, 8, 256)            0         ['bn4a_branch2b[0][0]']
#
#  res4a_branch1 (Conv2D)      (None, 8, 8, 1024)           525312    ['activation_21[0][0]']
#
#  res4a_branch2c (Conv2D)     (None, 8, 8, 1024)           263168    ['activation_23[0][0]']
#
#  bn4a_branch1 (BatchNormali  (None, 8, 8, 1024)           4096      ['res4a_branch1[0][0]']
#  zation)
#
#  bn4a_branch2c (BatchNormal  (None, 8, 8, 1024)           4096      ['res4a_branch2c[0][0]']
#  ization)
#
#  add_7 (Add)                 (None, 8, 8, 1024)           0         ['bn4a_branch1[0][0]',
#                                                                      'bn4a_branch2c[0][0]']
#
#  activation_24 (Activation)  (None, 8, 8, 1024)           0         ['add_7[0][0]']
#
#  res4b_branch2a (Conv2D)     (None, 8, 8, 256)            262400    ['activation_24[0][0]']
#
#  bn4b_branch2a (BatchNormal  (None, 8, 8, 256)            1024      ['res4b_branch2a[0][0]']
#  ization)
#
#  activation_25 (Activation)  (None, 8, 8, 256)            0         ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)     (None, 8, 8, 256)            590080    ['activation_25[0][0]']
#
#  bn4b_branch2b (BatchNormal  (None, 8, 8, 256)            1024      ['res4b_branch2b[0][0]']
#  ization)
#
#  activation_26 (Activation)  (None, 8, 8, 256)            0         ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)     (None, 8, 8, 1024)           263168    ['activation_26[0][0]']
#
#  bn4b_branch2c (BatchNormal  (None, 8, 8, 1024)           4096      ['res4b_branch2c[0][0]']
#  ization)
#
#  add_8 (Add)                 (None, 8, 8, 1024)           0         ['activation_24[0][0]',
#                                                                      'bn4b_branch2c[0][0]']
#
#  activation_27 (Activation)  (None, 8, 8, 1024)           0         ['add_8[0][0]']
#
#  res4c_branch2a (Conv2D)     (None, 8, 8, 256)            262400    ['activation_27[0][0]']
#
#  bn4c_branch2a (BatchNormal  (None, 8, 8, 256)            1024      ['res4c_branch2a[0][0]']
#  ization)
#
#  activation_28 (Activation)  (None, 8, 8, 256)            0         ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)     (None, 8, 8, 256)            590080    ['activation_28[0][0]']
#
#  bn4c_branch2b (BatchNormal  (None, 8, 8, 256)            1024      ['res4c_branch2b[0][0]']
#  ization)
#
#  activation_29 (Activation)  (None, 8, 8, 256)            0         ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)     (None, 8, 8, 1024)           263168    ['activation_29[0][0]']
#
#  bn4c_branch2c (BatchNormal  (None, 8, 8, 1024)           4096      ['res4c_branch2c[0][0]']
#  ization)
#
#  add_9 (Add)                 (None, 8, 8, 1024)           0         ['activation_27[0][0]',
#                                                                      'bn4c_branch2c[0][0]']
#
#  activation_30 (Activation)  (None, 8, 8, 1024)           0         ['add_9[0][0]']
#
#  res4d_branch2a (Conv2D)     (None, 8, 8, 256)            262400    ['activation_30[0][0]']
#
#  bn4d_branch2a (BatchNormal  (None, 8, 8, 256)            1024      ['res4d_branch2a[0][0]']
#  ization)
#
#  activation_31 (Activation)  (None, 8, 8, 256)            0         ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)     (None, 8, 8, 256)            590080    ['activation_31[0][0]']
#
#  bn4d_branch2b (BatchNormal  (None, 8, 8, 256)            1024      ['res4d_branch2b[0][0]']
#  ization)
#
#  activation_32 (Activation)  (None, 8, 8, 256)            0         ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)     (None, 8, 8, 1024)           263168    ['activation_32[0][0]']
#
#  bn4d_branch2c (BatchNormal  (None, 8, 8, 1024)           4096      ['res4d_branch2c[0][0]']
#  ization)
#
#  add_10 (Add)                (None, 8, 8, 1024)           0         ['activation_30[0][0]',
#                                                                      'bn4d_branch2c[0][0]']
#
#  activation_33 (Activation)  (None, 8, 8, 1024)           0         ['add_10[0][0]']
#
#  res4e_branch2a (Conv2D)     (None, 8, 8, 256)            262400    ['activation_33[0][0]']
#
#  bn4e_branch2a (BatchNormal  (None, 8, 8, 256)            1024      ['res4e_branch2a[0][0]']
#  ization)
#
#  activation_34 (Activation)  (None, 8, 8, 256)            0         ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)     (None, 8, 8, 256)            590080    ['activation_34[0][0]']
#
#  bn4e_branch2b (BatchNormal  (None, 8, 8, 256)            1024      ['res4e_branch2b[0][0]']
#  ization)
#
#  activation_35 (Activation)  (None, 8, 8, 256)            0         ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)     (None, 8, 8, 1024)           263168    ['activation_35[0][0]']
#
#  bn4e_branch2c (BatchNormal  (None, 8, 8, 1024)           4096      ['res4e_branch2c[0][0]']
#  ization)
#
#  add_11 (Add)                (None, 8, 8, 1024)           0         ['activation_33[0][0]',
#                                                                      'bn4e_branch2c[0][0]']
#
#  activation_36 (Activation)  (None, 8, 8, 1024)           0         ['add_11[0][0]']
#
#  res4f_branch2a (Conv2D)     (None, 8, 8, 256)            262400    ['activation_36[0][0]']
#
#  bn4f_branch2a (BatchNormal  (None, 8, 8, 256)            1024      ['res4f_branch2a[0][0]']
#  ization)
#
#  activation_37 (Activation)  (None, 8, 8, 256)            0         ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)     (None, 8, 8, 256)            590080    ['activation_37[0][0]']
#
#  bn4f_branch2b (BatchNormal  (None, 8, 8, 256)            1024      ['res4f_branch2b[0][0]']
#  ization)
#
#  activation_38 (Activation)  (None, 8, 8, 256)            0         ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)     (None, 8, 8, 1024)           263168    ['activation_38[0][0]']
#
#  bn4f_branch2c (BatchNormal  (None, 8, 8, 1024)           4096      ['res4f_branch2c[0][0]']
#  ization)
#
#  add_12 (Add)                (None, 8, 8, 1024)           0         ['activation_36[0][0]',
#                                                                      'bn4f_branch2c[0][0]']
#
#  activation_39 (Activation)  (None, 8, 8, 1024)           0         ['add_12[0][0]']
#
#  res5a_branch2a (Conv2D)     (None, 4, 4, 512)            524800    ['activation_39[0][0]']
#
#  bn5a_branch2a (BatchNormal  (None, 4, 4, 512)            2048      ['res5a_branch2a[0][0]']
#  ization)
#
#  activation_40 (Activation)  (None, 4, 4, 512)            0         ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)     (None, 4, 4, 512)            2359808   ['activation_40[0][0]']
#
#  bn5a_branch2b (BatchNormal  (None, 4, 4, 512)            2048      ['res5a_branch2b[0][0]']
#  ization)
#
#  activation_41 (Activation)  (None, 4, 4, 512)            0         ['bn5a_branch2b[0][0]']
#
#  res5a_branch1 (Conv2D)      (None, 4, 4, 2048)           2099200   ['activation_39[0][0]']
#
#  res5a_branch2c (Conv2D)     (None, 4, 4, 2048)           1050624   ['activation_41[0][0]']
#
#  bn5a_branch1 (BatchNormali  (None, 4, 4, 2048)           8192      ['res5a_branch1[0][0]']
#  zation)
#
#  bn5a_branch2c (BatchNormal  (None, 4, 4, 2048)           8192      ['res5a_branch2c[0][0]']
#  ization)
#
#  add_13 (Add)                (None, 4, 4, 2048)           0         ['bn5a_branch1[0][0]',
#                                                                      'bn5a_branch2c[0][0]']
#
#  activation_42 (Activation)  (None, 4, 4, 2048)           0         ['add_13[0][0]']
#
#  res5b_branch2a (Conv2D)     (None, 4, 4, 512)            1049088   ['activation_42[0][0]']
#
#  bn5b_branch2a (BatchNormal  (None, 4, 4, 512)            2048      ['res5b_branch2a[0][0]']
#  ization)
#
#  activation_43 (Activation)  (None, 4, 4, 512)            0         ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)     (None, 4, 4, 512)            2359808   ['activation_43[0][0]']
#
#  bn5b_branch2b (BatchNormal  (None, 4, 4, 512)            2048      ['res5b_branch2b[0][0]']
#  ization)
#
#  activation_44 (Activation)  (None, 4, 4, 512)            0         ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)     (None, 4, 4, 2048)           1050624   ['activation_44[0][0]']
#
#  bn5b_branch2c (BatchNormal  (None, 4, 4, 2048)           8192      ['res5b_branch2c[0][0]']
#  ization)
#
#  add_14 (Add)                (None, 4, 4, 2048)           0         ['activation_42[0][0]',
#                                                                      'bn5b_branch2c[0][0]']
#
#  activation_45 (Activation)  (None, 4, 4, 2048)           0         ['add_14[0][0]']
#
#  res5c_branch2a (Conv2D)     (None, 4, 4, 512)            1049088   ['activation_45[0][0]']
#
#  bn5c_branch2a (BatchNormal  (None, 4, 4, 512)            2048      ['res5c_branch2a[0][0]']
#  ization)
#
#  activation_46 (Activation)  (None, 4, 4, 512)            0         ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)     (None, 4, 4, 512)            2359808   ['activation_46[0][0]']
#
#  bn5c_branch2b (BatchNormal  (None, 4, 4, 512)            2048      ['res5c_branch2b[0][0]']
#  ization)
#
#  activation_47 (Activation)  (None, 4, 4, 512)            0         ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)     (None, 4, 4, 2048)           1050624   ['activation_47[0][0]']
#
#  bn5c_branch2c (BatchNormal  (None, 4, 4, 2048)           8192      ['res5c_branch2c[0][0]']
#  ization)
#
#  add_15 (Add)                (None, 4, 4, 2048)           0         ['activation_45[0][0]',
#                                                                      'bn5c_branch2c[0][0]']
#
#  activation_48 (Activation)  (None, 4, 4, 2048)           0         ['add_15[0][0]']
#
#  avg_pool (AveragePooling2D  (None, 2, 2, 2048)           0         ['activation_48[0][0]']
#  )
#
#  flatten (Flatten)           (None, 8192)                 0         ['avg_pool[0][0]']
#
#  fc124 (Dense)               (None, 124)                  1015932   ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 24597372 (93.83 MB)
# Trainable params: 24544252 (93.63 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Plot Training & Validation Accuracy

# %%
plt.plot(history.history['acc'], color='blue', label='Training Accuracy')
plt.plot(history.history['val_acc'],
         color='red', label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Plot Training and Validation Loss

# %%
plt.plot(history.history['loss'], color='blue', label='Training Loss')
plt.plot(history.history['val_loss'],
         color='red', label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Plot Training and Testing Top 5 Accuracy

# %%
plt.plot(history.history['top_5_accuracy'],
         color='blue', label='Training Accuracy')
plt.plot(history.history['val_top_5_accuracy'],
         color='red', label='Validation Accuracy')
plt.title('Model Top 5 Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
