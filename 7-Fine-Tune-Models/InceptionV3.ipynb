# %% [markdown]
# ### Import the Libraries

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import top_k_categorical_accuracy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout
# Out:
# 2024-04-14 12:21:29.121288: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-14 12:21:29.176257: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-14 12:21:30.194167: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/saad-bscs/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ### Constants

# %%
batch_size = 32
num_classes = 124
tf.random.set_seed(42)
img_height, img_width = 128, 128
data_dir = os.path.join(os.getcwd(), "../5-Gait-Energy-Images")

# %% [markdown]
# ### Training Data Augmentation

# %%
train_datagen = ImageDataGenerator(
    shear_range=0.2,
    rescale=1.0 / 255,
    rotation_range=20,
    fill_mode="nearest",
    horizontal_flip=True,
    zoom_range=[0.8, 1.2],
    width_shift_range=0.2,
    validation_split=0.15,
    height_shift_range=0.2,
    channel_shift_range=10,
    brightness_range=[0.8, 1.2],
)

# %% [markdown]
# ### Testing Data Augmentation

# %%
test_datagen = ImageDataGenerator(rescale=1.0 / 255, validation_split=0.15)

# %% [markdown]
# ### Load and Split Data into Training and Testing Sets

# %%
train_generator = train_datagen.flow_from_directory(
    data_dir,
    seed=42,
    shuffle=True,
    subset="training",
    batch_size=batch_size,
    class_mode="categorical",
    target_size=(img_height, img_width),
)

test_generator = test_datagen.flow_from_directory(
    data_dir,
    seed=42,
    shuffle=False,
    subset="validation",
    batch_size=batch_size,
    class_mode="categorical",
    target_size=(img_height, img_width),
)
# Out:
# Found 11587 images belonging to 124 classes.
# Found 1974 images belonging to 124 classes.

# %% [markdown]
# ### Load Pre-Trained InceptionV3 without Top Layers

# %%
base_model = InceptionV3(
    weights="imagenet", include_top=False, input_shape=(img_height, img_width, 3)
)
# Out:
# 2024-04-14 12:21:33.680238: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### Add custom classification layers

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation="relu", kernel_regularizer=l2(0.003))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation="relu", kernel_regularizer=l2(0.003))(x)
predictions = Dense(num_classes, activation='linear',
                    kernel_regularizer=l2(0.003))(x)

# %% [markdown]
# ### Create the model

# %%
model = Model(inputs=base_model.input, outputs=predictions)

# %% [markdown]
# ### Fine Tune the layers

# %%
for layer in model.layers:
    layer.trainable = True

# %% [markdown]
# ### Define Top k Accuracy Function

# %%
def top_5_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=5)

# %% [markdown]
# ### Compile the model

# %%
model.compile(
    optimizer=RMSprop(
        rho=0.9,
        momentum=0.0,
        epsilon=1e-07,
        name="RMSprop",
        centered=False,
        learning_rate=1e-4,
    ),
    loss=CategoricalCrossentropy(from_logits=True),
    metrics=["acc", top_5_accuracy],
)

# %% [markdown]
# ### Define the Callbacks

# %%
checkpoint = ModelCheckpoint(
    "best_model.h5", monitor='val_acc', save_best_only=True, mode='max')
early_stopping = EarlyStopping(
    monitor='val_acc', patience=30, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(
    monitor='val_acc', factor=0.1, patience=5, min_lr=1e-7)

# %% [markdown]
# ### Train the model

# %%
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=500,
    callbacks=[checkpoint, early_stopping, reduce_lr],
    use_multiprocessing=True)
# Out:
# Epoch 1/500
# 363/363 [==============================] - ETA: 0s - loss: 12.9276 - acc: 0.0098 - top_5_accuracy: 0.0514
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 363/363 [==============================] - 181s 464ms/step - loss: 12.9276 - acc: 0.0098 - top_5_accuracy: 0.0514 - val_loss: 12.1489 - val_acc: 0.0198 - val_top_5_accuracy: 0.0871 - lr: 1.0000e-04
# Epoch 2/500
# 363/363 [==============================] - 171s 467ms/step - loss: 12.1720 - acc: 0.0161 - top_5_accuracy: 0.0710 - val_loss: 11.3689 - val_acc: 0.0410 - val_top_5_accuracy: 0.1505 - lr: 1.0000e-04
# Epoch 3/500
# 363/363 [==============================] - 161s 440ms/step - loss: 11.3524 - acc: 0.0318 - top_5_accuracy: 0.1265 - val_loss: 10.9903 - val_acc: 0.0699 - val_top_5_accuracy: 0.2275 - lr: 1.0000e-04
# Epoch 4/500
# 363/363 [==============================] - 162s 443ms/step - loss: 10.4416 - acc: 0.0665 - top_5_accuracy: 0.2082 - val_loss: 9.5276 - val_acc: 0.1277 - val_top_5_accuracy: 0.3430 - lr: 1.0000e-04
# Epoch 5/500
# 363/363 [==============================] - 161s 441ms/step - loss: 9.5310 - acc: 0.1068 - top_5_accuracy: 0.3067 - val_loss: 8.7465 - val_acc: 0.1591 - val_top_5_accuracy: 0.4286 - lr: 1.0000e-04
# Epoch 6/500
# 363/363 [==============================] - 161s 440ms/step - loss: 8.6366 - acc: 0.1585 - top_5_accuracy: 0.4197 - val_loss: 8.3320 - val_acc: 0.1859 - val_top_5_accuracy: 0.4498 - lr: 1.0000e-04
# Epoch 7/500
# 363/363 [==============================] - 161s 439ms/step - loss: 7.9016 - acc: 0.2155 - top_5_accuracy: 0.5025 - val_loss: 7.2506 - val_acc: 0.2852 - val_top_5_accuracy: 0.6130 - lr: 1.0000e-04
# Epoch 8/500
# 363/363 [==============================] - 167s 455ms/step - loss: 7.2582 - acc: 0.2753 - top_5_accuracy: 0.5897 - val_loss: 6.9045 - val_acc: 0.2908 - val_top_5_accuracy: 0.6180 - lr: 1.0000e-04
# Epoch 9/500
# 363/363 [==============================] - 160s 438ms/step - loss: 6.7166 - acc: 0.3267 - top_5_accuracy: 0.6479 - val_loss: 6.6622 - val_acc: 0.3212 - val_top_5_accuracy: 0.6657 - lr: 1.0000e-04
# Epoch 10/500
# 363/363 [==============================] - 160s 436ms/step - loss: 6.1941 - acc: 0.3926 - top_5_accuracy: 0.7093 - val_loss: 5.9405 - val_acc: 0.4245 - val_top_5_accuracy: 0.7492 - lr: 1.0000e-04
# Epoch 11/500
# 363/363 [==============================] - 159s 435ms/step - loss: 5.7774 - acc: 0.4322 - top_5_accuracy: 0.7488 - val_loss: 5.7117 - val_acc: 0.4200 - val_top_5_accuracy: 0.7563 - lr: 1.0000e-04
# Epoch 12/500
# 363/363 [==============================] - 161s 439ms/step - loss: 5.3851 - acc: 0.4811 - top_5_accuracy: 0.7880 - val_loss: 5.3913 - val_acc: 0.4549 - val_top_5_accuracy: 0.7933 - lr: 1.0000e-04
# Epoch 13/500
# 363/363 [==============================] - 162s 443ms/step - loss: 5.0189 - acc: 0.5164 - top_5_accuracy: 0.8155 - val_loss: 5.2626 - val_acc: 0.4676 - val_top_5_accuracy: 0.7801 - lr: 1.0000e-04
# Epoch 14/500
# 363/363 [==============================] - 157s 428ms/step - loss: 4.6670 - acc: 0.5672 - top_5_accuracy: 0.8444 - val_loss: 5.5853 - val_acc: 0.3916 - val_top_5_accuracy: 0.7143 - lr: 1.0000e-04
# Epoch 15/500
# 363/363 [==============================] - 163s 444ms/step - loss: 4.3796 - acc: 0.5919 - top_5_accuracy: 0.8598 - val_loss: 4.5896 - val_acc: 0.5243 - val_top_5_accuracy: 0.8242 - lr: 1.0000e-04
# Epoch 16/500
# 363/363 [==============================] - 161s 439ms/step - loss: 4.0918 - acc: 0.6349 - top_5_accuracy: 0.8840 - val_loss: 4.2773 - val_acc: 0.5608 - val_top_5_accuracy: 0.8546 - lr: 1.0000e-04
# Epoch 17/500
# 363/363 [==============================] - 162s 442ms/step - loss: 3.8315 - acc: 0.6630 - top_5_accuracy: 0.9020 - val_loss: 4.1824 - val_acc: 0.5679 - val_top_5_accuracy: 0.8323 - lr: 1.0000e-04
# Epoch 18/500
# 363/363 [==============================] - 160s 438ms/step - loss: 3.5947 - acc: 0.6875 - top_5_accuracy: 0.9153 - val_loss: 4.3128 - val_acc: 0.5172 - val_top_5_accuracy: 0.8075 - lr: 1.0000e-04
# Epoch 19/500
# 363/363 [==============================] - 160s 435ms/step - loss: 3.3766 - acc: 0.7118 - top_5_accuracy: 0.9284 - val_loss: 3.8631 - val_acc: 0.5729 - val_top_5_accuracy: 0.8546 - lr: 1.0000e-04
# Epoch 20/500
# 363/363 [==============================] - 161s 440ms/step - loss: 3.1771 - acc: 0.7334 - top_5_accuracy: 0.9331 - val_loss: 3.7880 - val_acc: 0.5821 - val_top_5_accuracy: 0.8409 - lr: 1.0000e-04
# Epoch 21/500
# 363/363 [==============================] - 160s 436ms/step - loss: 2.9849 - acc: 0.7548 - top_5_accuracy: 0.9434 - val_loss: 4.1126 - val_acc: 0.5005 - val_top_5_accuracy: 0.8050 - lr: 1.0000e-04
# Epoch 22/500
# 363/363 [==============================] - 160s 437ms/step - loss: 2.8053 - acc: 0.7718 - top_5_accuracy: 0.9499 - val_loss: 3.4948 - val_acc: 0.6039 - val_top_5_accuracy: 0.8561 - lr: 1.0000e-04
# Epoch 23/500
# 363/363 [==============================] - 160s 437ms/step - loss: 2.6787 - acc: 0.7785 - top_5_accuracy: 0.9512 - val_loss: 3.1911 - val_acc: 0.6525 - val_top_5_accuracy: 0.8835 - lr: 1.0000e-04
# Epoch 24/500
# 363/363 [==============================] - 155s 425ms/step - loss: 2.5057 - acc: 0.8052 - top_5_accuracy: 0.9606 - val_loss: 3.1259 - val_acc: 0.6403 - val_top_5_accuracy: 0.8815 - lr: 1.0000e-04
# Epoch 25/500
# 363/363 [==============================] - 163s 445ms/step - loss: 2.3753 - acc: 0.8105 - top_5_accuracy: 0.9641 - val_loss: 2.8411 - val_acc: 0.6869 - val_top_5_accuracy: 0.9022 - lr: 1.0000e-04
# Epoch 26/500
# 363/363 [==============================] - 163s 444ms/step - loss: 2.2636 - acc: 0.8253 - top_5_accuracy: 0.9673 - val_loss: 2.6202 - val_acc: 0.7138 - val_top_5_accuracy: 0.9260 - lr: 1.0000e-04
# Epoch 27/500
# 363/363 [==============================] - 158s 431ms/step - loss: 2.1573 - acc: 0.8308 - top_5_accuracy: 0.9691 - val_loss: 3.1064 - val_acc: 0.5922 - val_top_5_accuracy: 0.8602 - lr: 1.0000e-04
# Epoch 28/500
# 363/363 [==============================] - 158s 428ms/step - loss: 2.0567 - acc: 0.8427 - top_5_accuracy: 0.9720 - val_loss: 2.9371 - val_acc: 0.6337 - val_top_5_accuracy: 0.8668 - lr: 1.0000e-04
# Epoch 29/500
# 363/363 [==============================] - 161s 438ms/step - loss: 1.9591 - acc: 0.8572 - top_5_accuracy: 0.9739 - val_loss: 2.7410 - val_acc: 0.6505 - val_top_5_accuracy: 0.8926 - lr: 1.0000e-04
# Epoch 30/500
# 363/363 [==============================] - 160s 436ms/step - loss: 1.8491 - acc: 0.8686 - top_5_accuracy: 0.9770 - val_loss: 2.4796 - val_acc: 0.7021 - val_top_5_accuracy: 0.9134 - lr: 1.0000e-04
# Epoch 31/500
# 363/363 [==============================] - 158s 431ms/step - loss: 1.8024 - acc: 0.8657 - top_5_accuracy: 0.9770 - val_loss: 2.9198 - val_acc: 0.6114 - val_top_5_accuracy: 0.8541 - lr: 1.0000e-04
# Epoch 32/500
# 363/363 [==============================] - 162s 441ms/step - loss: 1.6528 - acc: 0.8998 - top_5_accuracy: 0.9858 - val_loss: 2.1896 - val_acc: 0.7563 - val_top_5_accuracy: 0.9291 - lr: 1.0000e-05
# Epoch 33/500
# 363/363 [==============================] - 162s 441ms/step - loss: 1.5694 - acc: 0.9234 - top_5_accuracy: 0.9886 - val_loss: 2.1106 - val_acc: 0.7801 - val_top_5_accuracy: 0.9372 - lr: 1.0000e-05
# Epoch 34/500
# 363/363 [==============================] - 159s 434ms/step - loss: 1.5241 - acc: 0.9296 - top_5_accuracy: 0.9907 - val_loss: 2.0613 - val_acc: 0.7862 - val_top_5_accuracy: 0.9402 - lr: 1.0000e-05
# Epoch 35/500
# 363/363 [==============================] - 161s 441ms/step - loss: 1.5103 - acc: 0.9271 - top_5_accuracy: 0.9913 - val_loss: 2.0175 - val_acc: 0.7888 - val_top_5_accuracy: 0.9422 - lr: 1.0000e-05
# Epoch 36/500
# 363/363 [==============================] - 161s 439ms/step - loss: 1.4816 - acc: 0.9328 - top_5_accuracy: 0.9920 - val_loss: 2.0217 - val_acc: 0.7857 - val_top_5_accuracy: 0.9422 - lr: 1.0000e-05
# Epoch 37/500
# 363/363 [==============================] - 160s 437ms/step - loss: 1.4653 - acc: 0.9330 - top_5_accuracy: 0.9917 - val_loss: 2.0029 - val_acc: 0.7928 - val_top_5_accuracy: 0.9422 - lr: 1.0000e-05
# Epoch 38/500
# 363/363 [==============================] - 165s 450ms/step - loss: 1.4308 - acc: 0.9424 - top_5_accuracy: 0.9927 - val_loss: 1.9943 - val_acc: 0.7903 - val_top_5_accuracy: 0.9433 - lr: 1.0000e-05
# Epoch 39/500
# 363/363 [==============================] - 162s 441ms/step - loss: 1.4177 - acc: 0.9408 - top_5_accuracy: 0.9950 - val_loss: 1.9563 - val_acc: 0.7938 - val_top_5_accuracy: 0.9463 - lr: 1.0000e-05
# Epoch 40/500
# 363/363 [==============================] - 161s 439ms/step - loss: 1.3986 - acc: 0.9428 - top_5_accuracy: 0.9927 - val_loss: 1.9614 - val_acc: 0.7862 - val_top_5_accuracy: 0.9402 - lr: 1.0000e-05
# Epoch 41/500
# 363/363 [==============================] - 162s 441ms/step - loss: 1.3796 - acc: 0.9449 - top_5_accuracy: 0.9924 - val_loss: 1.9224 - val_acc: 0.7958 - val_top_5_accuracy: 0.9438 - lr: 1.0000e-05
# Epoch 42/500
# 363/363 [==============================] - 161s 440ms/step - loss: 1.3580 - acc: 0.9449 - top_5_accuracy: 0.9949 - val_loss: 1.8859 - val_acc: 0.8029 - val_top_5_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 43/500
# 363/363 [==============================] - 159s 433ms/step - loss: 1.3476 - acc: 0.9467 - top_5_accuracy: 0.9938 - val_loss: 1.8522 - val_acc: 0.8075 - val_top_5_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 44/500
# 363/363 [==============================] - 162s 442ms/step - loss: 1.3287 - acc: 0.9474 - top_5_accuracy: 0.9938 - val_loss: 1.8176 - val_acc: 0.8126 - val_top_5_accuracy: 0.9569 - lr: 1.0000e-05
# Epoch 45/500
# 363/363 [==============================] - 160s 438ms/step - loss: 1.3168 - acc: 0.9468 - top_5_accuracy: 0.9945 - val_loss: 1.8473 - val_acc: 0.8009 - val_top_5_accuracy: 0.9453 - lr: 1.0000e-05
# Epoch 46/500
# 363/363 [==============================] - 162s 440ms/step - loss: 1.3042 - acc: 0.9487 - top_5_accuracy: 0.9940 - val_loss: 1.8110 - val_acc: 0.8070 - val_top_5_accuracy: 0.9519 - lr: 1.0000e-05
# Epoch 47/500
# 363/363 [==============================] - 167s 454ms/step - loss: 1.2863 - acc: 0.9500 - top_5_accuracy: 0.9942 - val_loss: 1.7887 - val_acc: 0.8131 - val_top_5_accuracy: 0.9529 - lr: 1.0000e-05
# Epoch 48/500
# 363/363 [==============================] - 157s 427ms/step - loss: 1.2643 - acc: 0.9523 - top_5_accuracy: 0.9959 - val_loss: 1.7889 - val_acc: 0.8060 - val_top_5_accuracy: 0.9539 - lr: 1.0000e-05
# Epoch 49/500
# 363/363 [==============================] - 161s 440ms/step - loss: 1.2488 - acc: 0.9553 - top_5_accuracy: 0.9947 - val_loss: 1.7823 - val_acc: 0.8105 - val_top_5_accuracy: 0.9488 - lr: 1.0000e-05
# Epoch 50/500
# 363/363 [==============================] - 160s 436ms/step - loss: 1.2294 - acc: 0.9550 - top_5_accuracy: 0.9957 - val_loss: 1.7209 - val_acc: 0.8217 - val_top_5_accuracy: 0.9539 - lr: 1.0000e-05
# Epoch 51/500
# 363/363 [==============================] - 161s 438ms/step - loss: 1.2217 - acc: 0.9535 - top_5_accuracy: 0.9950 - val_loss: 1.7182 - val_acc: 0.8232 - val_top_5_accuracy: 0.9534 - lr: 1.0000e-05
# Epoch 52/500
# 363/363 [==============================] - 159s 433ms/step - loss: 1.2124 - acc: 0.9549 - top_5_accuracy: 0.9954 - val_loss: 1.7194 - val_acc: 0.8131 - val_top_5_accuracy: 0.9544 - lr: 1.0000e-05
# Epoch 53/500
# 363/363 [==============================] - 163s 444ms/step - loss: 1.1938 - acc: 0.9571 - top_5_accuracy: 0.9959 - val_loss: 1.6874 - val_acc: 0.8242 - val_top_5_accuracy: 0.9559 - lr: 1.0000e-05
# Epoch 54/500
# 363/363 [==============================] - 159s 434ms/step - loss: 1.1871 - acc: 0.9566 - top_5_accuracy: 0.9954 - val_loss: 1.6583 - val_acc: 0.8242 - val_top_5_accuracy: 0.9580 - lr: 1.0000e-05
# Epoch 55/500
# 363/363 [==============================] - 156s 425ms/step - loss: 1.1671 - acc: 0.9585 - top_5_accuracy: 0.9965 - val_loss: 1.6798 - val_acc: 0.8186 - val_top_5_accuracy: 0.9539 - lr: 1.0000e-05
# Epoch 56/500
# 363/363 [==============================] - 164s 449ms/step - loss: 1.1606 - acc: 0.9586 - top_5_accuracy: 0.9945 - val_loss: 1.6644 - val_acc: 0.8161 - val_top_5_accuracy: 0.9554 - lr: 1.0000e-05
# Epoch 57/500
# 363/363 [==============================] - 159s 435ms/step - loss: 1.1469 - acc: 0.9590 - top_5_accuracy: 0.9964 - val_loss: 1.6466 - val_acc: 0.8186 - val_top_5_accuracy: 0.9564 - lr: 1.0000e-05
# Epoch 58/500
# 363/363 [==============================] - 164s 449ms/step - loss: 1.1384 - acc: 0.9587 - top_5_accuracy: 0.9953 - val_loss: 1.6548 - val_acc: 0.8105 - val_top_5_accuracy: 0.9539 - lr: 1.0000e-05
# Epoch 59/500
# 363/363 [==============================] - 164s 448ms/step - loss: 1.1293 - acc: 0.9600 - top_5_accuracy: 0.9954 - val_loss: 1.6241 - val_acc: 0.8247 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-06
# Epoch 60/500
# 363/363 [==============================] - 163s 444ms/step - loss: 1.1182 - acc: 0.9620 - top_5_accuracy: 0.9961 - val_loss: 1.6242 - val_acc: 0.8262 - val_top_5_accuracy: 0.9580 - lr: 1.0000e-06
# Epoch 61/500
# 363/363 [==============================] - 162s 441ms/step - loss: 1.1188 - acc: 0.9631 - top_5_accuracy: 0.9957 - val_loss: 1.6233 - val_acc: 0.8217 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-06
# Epoch 62/500
# 363/363 [==============================] - 161s 436ms/step - loss: 1.1205 - acc: 0.9625 - top_5_accuracy: 0.9964 - val_loss: 1.6146 - val_acc: 0.8217 - val_top_5_accuracy: 0.9580 - lr: 1.0000e-06
# Epoch 63/500
# 363/363 [==============================] - 156s 425ms/step - loss: 1.1144 - acc: 0.9638 - top_5_accuracy: 0.9961 - val_loss: 1.6204 - val_acc: 0.8227 - val_top_5_accuracy: 0.9569 - lr: 1.0000e-06
# Epoch 64/500
# 363/363 [==============================] - 164s 446ms/step - loss: 1.1181 - acc: 0.9621 - top_5_accuracy: 0.9962 - val_loss: 1.6208 - val_acc: 0.8252 - val_top_5_accuracy: 0.9564 - lr: 1.0000e-06
# Epoch 65/500
# 363/363 [==============================] - 159s 431ms/step - loss: 1.1002 - acc: 0.9670 - top_5_accuracy: 0.9966 - val_loss: 1.6147 - val_acc: 0.8217 - val_top_5_accuracy: 0.9580 - lr: 1.0000e-06
# Epoch 66/500
# 363/363 [==============================] - 161s 441ms/step - loss: 1.1058 - acc: 0.9638 - top_5_accuracy: 0.9963 - val_loss: 1.6118 - val_acc: 0.8242 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 67/500
# 363/363 [==============================] - 161s 439ms/step - loss: 1.1021 - acc: 0.9663 - top_5_accuracy: 0.9969 - val_loss: 1.6161 - val_acc: 0.8217 - val_top_5_accuracy: 0.9580 - lr: 1.0000e-07
# Epoch 68/500
# 363/363 [==============================] - 158s 428ms/step - loss: 1.1092 - acc: 0.9638 - top_5_accuracy: 0.9962 - val_loss: 1.6105 - val_acc: 0.8232 - val_top_5_accuracy: 0.9585 - lr: 1.0000e-07
# Epoch 69/500
# 363/363 [==============================] - 164s 448ms/step - loss: 1.1079 - acc: 0.9657 - top_5_accuracy: 0.9968 - val_loss: 1.6071 - val_acc: 0.8283 - val_top_5_accuracy: 0.9590 - lr: 1.0000e-07
# Epoch 70/500
# 363/363 [==============================] - 164s 449ms/step - loss: 1.1090 - acc: 0.9616 - top_5_accuracy: 0.9959 - val_loss: 1.6169 - val_acc: 0.8217 - val_top_5_accuracy: 0.9564 - lr: 1.0000e-07
# Epoch 71/500
# 363/363 [==============================] - 163s 444ms/step - loss: 1.1087 - acc: 0.9629 - top_5_accuracy: 0.9965 - val_loss: 1.6122 - val_acc: 0.8262 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 72/500
# 363/363 [==============================] - 157s 428ms/step - loss: 1.1046 - acc: 0.9653 - top_5_accuracy: 0.9965 - val_loss: 1.6081 - val_acc: 0.8262 - val_top_5_accuracy: 0.9580 - lr: 1.0000e-07
# Epoch 73/500
# 363/363 [==============================] - 160s 436ms/step - loss: 1.0971 - acc: 0.9673 - top_5_accuracy: 0.9972 - val_loss: 1.6104 - val_acc: 0.8247 - val_top_5_accuracy: 0.9590 - lr: 1.0000e-07
# Epoch 74/500
# 363/363 [==============================] - 160s 436ms/step - loss: 1.1086 - acc: 0.9617 - top_5_accuracy: 0.9971 - val_loss: 1.6122 - val_acc: 0.8257 - val_top_5_accuracy: 0.9580 - lr: 1.0000e-07
# Epoch 75/500
# 363/363 [==============================] - 159s 432ms/step - loss: 1.1017 - acc: 0.9657 - top_5_accuracy: 0.9965 - val_loss: 1.6095 - val_acc: 0.8207 - val_top_5_accuracy: 0.9595 - lr: 1.0000e-07
# Epoch 76/500
# 363/363 [==============================] - 159s 435ms/step - loss: 1.1074 - acc: 0.9630 - top_5_accuracy: 0.9963 - val_loss: 1.6169 - val_acc: 0.8262 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 77/500
# 363/363 [==============================] - 161s 437ms/step - loss: 1.1093 - acc: 0.9612 - top_5_accuracy: 0.9959 - val_loss: 1.6135 - val_acc: 0.8267 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 78/500
# 363/363 [==============================] - 161s 440ms/step - loss: 1.1051 - acc: 0.9651 - top_5_accuracy: 0.9966 - val_loss: 1.6041 - val_acc: 0.8273 - val_top_5_accuracy: 0.9590 - lr: 1.0000e-07
# Epoch 79/500
# 363/363 [==============================] - 164s 446ms/step - loss: 1.1008 - acc: 0.9647 - top_5_accuracy: 0.9965 - val_loss: 1.6190 - val_acc: 0.8227 - val_top_5_accuracy: 0.9580 - lr: 1.0000e-07
# Epoch 80/500
# 363/363 [==============================] - 160s 436ms/step - loss: 1.1092 - acc: 0.9633 - top_5_accuracy: 0.9962 - val_loss: 1.6161 - val_acc: 0.8267 - val_top_5_accuracy: 0.9569 - lr: 1.0000e-07
# Epoch 81/500
# 363/363 [==============================] - 158s 431ms/step - loss: 1.1044 - acc: 0.9640 - top_5_accuracy: 0.9964 - val_loss: 1.6099 - val_acc: 0.8278 - val_top_5_accuracy: 0.9585 - lr: 1.0000e-07
# Epoch 82/500
# 363/363 [==============================] - 160s 434ms/step - loss: 1.1120 - acc: 0.9644 - top_5_accuracy: 0.9962 - val_loss: 1.6120 - val_acc: 0.8273 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 83/500
# 363/363 [==============================] - 158s 431ms/step - loss: 1.1119 - acc: 0.9607 - top_5_accuracy: 0.9965 - val_loss: 1.6119 - val_acc: 0.8257 - val_top_5_accuracy: 0.9559 - lr: 1.0000e-07
# Epoch 84/500
# 363/363 [==============================] - 164s 445ms/step - loss: 1.0994 - acc: 0.9662 - top_5_accuracy: 0.9966 - val_loss: 1.6070 - val_acc: 0.8232 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 85/500
# 363/363 [==============================] - 158s 430ms/step - loss: 1.1072 - acc: 0.9631 - top_5_accuracy: 0.9964 - val_loss: 1.6103 - val_acc: 0.8257 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 86/500
# 363/363 [==============================] - 172s 468ms/step - loss: 1.1089 - acc: 0.9632 - top_5_accuracy: 0.9965 - val_loss: 1.6058 - val_acc: 0.8232 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 87/500
# 363/363 [==============================] - 160s 437ms/step - loss: 1.1082 - acc: 0.9643 - top_5_accuracy: 0.9958 - val_loss: 1.6040 - val_acc: 0.8273 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 88/500
# 363/363 [==============================] - 163s 443ms/step - loss: 1.1045 - acc: 0.9645 - top_5_accuracy: 0.9965 - val_loss: 1.6189 - val_acc: 0.8232 - val_top_5_accuracy: 0.9554 - lr: 1.0000e-07
# Epoch 89/500
# 363/363 [==============================] - 161s 439ms/step - loss: 1.1015 - acc: 0.9674 - top_5_accuracy: 0.9969 - val_loss: 1.6110 - val_acc: 0.8257 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 90/500
# 363/363 [==============================] - 166s 452ms/step - loss: 1.0998 - acc: 0.9630 - top_5_accuracy: 0.9974 - val_loss: 1.6030 - val_acc: 0.8283 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 91/500
# 363/363 [==============================] - 156s 425ms/step - loss: 1.1071 - acc: 0.9638 - top_5_accuracy: 0.9963 - val_loss: 1.6155 - val_acc: 0.8242 - val_top_5_accuracy: 0.9569 - lr: 1.0000e-07
# Epoch 92/500
# 363/363 [==============================] - 162s 441ms/step - loss: 1.1093 - acc: 0.9619 - top_5_accuracy: 0.9960 - val_loss: 1.6063 - val_acc: 0.8262 - val_top_5_accuracy: 0.9569 - lr: 1.0000e-07
# Epoch 93/500
# 363/363 [==============================] - 160s 436ms/step - loss: 1.1046 - acc: 0.9635 - top_5_accuracy: 0.9968 - val_loss: 1.6119 - val_acc: 0.8252 - val_top_5_accuracy: 0.9574 - lr: 1.0000e-07
# Epoch 94/500
# 363/363 [==============================] - 162s 443ms/step - loss: 1.1114 - acc: 0.9629 - top_5_accuracy: 0.9964 - val_loss: 1.6136 - val_acc: 0.8252 - val_top_5_accuracy: 0.9564 - lr: 1.0000e-07
# Epoch 95/500
# 363/363 [==============================] - 163s 444ms/step - loss: 1.1064 - acc: 0.9633 - top_5_accuracy: 0.9953 - val_loss: 1.6101 - val_acc: 0.8262 - val_top_5_accuracy: 0.9564 - lr: 1.0000e-07
# Epoch 96/500
# 363/363 [==============================] - 160s 435ms/step - loss: 1.1010 - acc: 0.9650 - top_5_accuracy: 0.9959 - val_loss: 1.6060 - val_acc: 0.8283 - val_top_5_accuracy: 0.9564 - lr: 1.0000e-07
# Epoch 97/500
# 363/363 [==============================] - 164s 446ms/step - loss: 1.1007 - acc: 0.9658 - top_5_accuracy: 0.9969 - val_loss: 1.6171 - val_acc: 0.8207 - val_top_5_accuracy: 0.9559 - lr: 1.0000e-07
# Epoch 98/500
# 363/363 [==============================] - 160s 436ms/step - loss: 1.1058 - acc: 0.9630 - top_5_accuracy: 0.9966 - val_loss: 1.6098 - val_acc: 0.8267 - val_top_5_accuracy: 0.9559 - lr: 1.0000e-07
# Epoch 99/500
# 363/363 [==============================] - 163s 444ms/step - loss: 1.1004 - acc: 0.9661 - top_5_accuracy: 0.9963 - val_loss: 1.6223 - val_acc: 0.8207 - val_top_5_accuracy: 0.9554 - lr: 1.0000e-07

# %% [markdown]
# ### Evaluate Model on Training Set

# %%
train_loss, train_accuracy, top5train = model.evaluate(train_generator)
print(f"Training Loss: {round(train_loss, 2)}")
print(f"Training Accuracy: {round(train_accuracy, 2)}")
print(f"Training Top 5 Accuracy: {round(top5train, 2)}")
# Out:
# 363/363 [==============================] - 79s 218ms/step - loss: 0.9873 - acc: 0.9882 - top_5_accuracy: 0.9984
# Training Loss: 0.99
# Training Accuracy: 0.99
# Training Top 5 Accuracy: 1.0

# %% [markdown]
# ### Evaluate Model on Testing Set

# %%
test_loss, test_accuracy, top5test = model.evaluate(test_generator)
print(f"Testing Loss: {round(test_loss, 2)}")
print(f"Testing Accuracy: {round(test_accuracy, 2)}")
print(f"Testing Top 5 Accuracy: {round(top5test, 2)}")
# Out:
# 62/62 [==============================] - 6s 95ms/step - loss: 1.6071 - acc: 0.8283 - top_5_accuracy: 0.9590
# Testing Loss: 1.61
# Testing Accuracy: 0.83
# Testing Top 5 Accuracy: 0.96

# %% [markdown]
# ### Save the Model

# %%
model.save('../9-Trained-Fine-Tune-Models/InceptionV3.h5')

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 63, 63, 32)           864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 63, 63, 32)           96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 63, 63, 32)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)           9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 61, 61, 32)           96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 61, 61, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 61, 61, 64)           18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 61, 61, 64)           192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 61, 61, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 30, 30, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 30, 30, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 30, 30, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 30, 30, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 28, 28, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 28, 28, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 13, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 13, 13, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 13, 13, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 13, 13, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 13, 13, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 13, 13, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 13, 13, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 13, 13, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 13, 13, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 13, 13, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 13, 13, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 13, 13, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 13, 13, 32)           6144      ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 13, 13, 64)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 13, 13, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 13, 13, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 13, 13, 32)           96        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 13, 13, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 13, 13, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 13, 13, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 13, 13, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed0 (Concatenate)        (None, 13, 13, 256)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 13, 13, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_15 (Ba  (None, 13, 13, 64)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 13, 13, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 13, 13, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 13, 13, 96)           55296     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 13, 13, 48)           144       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 13, 13, 96)           288       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 13, 13, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 13, 13, 96)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 13, 13, 256)          0         ['mixed0[0][0]']
#  gePooling2D)
#
#  conv2d_12 (Conv2D)          (None, 13, 13, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 13, 13, 64)           76800     ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 13, 13, 96)           82944     ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 13, 13, 64)           16384     ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 13, 13, 64)           192       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 13, 13, 64)           192       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 13, 13, 96)           288       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 13, 13, 64)           192       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 13, 13, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 13, 13, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 13, 13, 96)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 13, 13, 64)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 13, 13, 288)          0         ['activation_12[0][0]',
#                                                                      'activation_14[0][0]',
#                                                                      'activation_17[0][0]',
#                                                                      'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 13, 13, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_22 (Ba  (None, 13, 13, 64)           192       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 13, 13, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 13, 13, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 13, 13, 96)           55296     ['activation_22[0][0]']
#
#  batch_normalization_20 (Ba  (None, 13, 13, 48)           144       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 13, 13, 96)           288       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 13, 13, 48)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 13, 13, 96)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  average_pooling2d_2 (Avera  (None, 13, 13, 288)          0         ['mixed1[0][0]']
#  gePooling2D)
#
#  conv2d_19 (Conv2D)          (None, 13, 13, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 13, 13, 64)           76800     ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 13, 13, 96)           82944     ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 13, 13, 64)           18432     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (Ba  (None, 13, 13, 64)           192       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 13, 13, 64)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 13, 13, 96)           288       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 13, 13, 64)           192       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 13, 13, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 13, 13, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 13, 13, 96)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 13, 13, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 13, 13, 288)          0         ['activation_19[0][0]',
#                                                                      'activation_21[0][0]',
#                                                                      'activation_24[0][0]',
#                                                                      'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 13, 13, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_27 (Ba  (None, 13, 13, 64)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 13, 13, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 13, 13, 96)           55296     ['activation_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 13, 13, 96)           288       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 13, 13, 96)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 6, 6, 384)            995328    ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 6, 6, 96)             82944     ['activation_28[0][0]']
#
#  batch_normalization_26 (Ba  (None, 6, 6, 384)            1152      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 6, 6, 96)             288       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 6, 6, 384)            0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 6, 6, 96)             0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 288)            0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 6, 6, 768)            0         ['activation_26[0][0]',
#                                                                      'activation_29[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 6, 6, 128)            98304     ['mixed3[0][0]']
#
#  batch_normalization_34 (Ba  (None, 6, 6, 128)            384       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 6, 6, 128)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 6, 6, 128)            114688    ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 6, 6, 128)            384       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 6, 6, 128)            0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 6, 6, 128)            98304     ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 6, 6, 128)            114688    ['activation_35[0][0]']
#
#  batch_normalization_31 (Ba  (None, 6, 6, 128)            384       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 6, 6, 128)            384       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 6, 6, 128)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 6, 6, 128)            0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 6, 6, 128)            114688    ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 6, 6, 128)            114688    ['activation_36[0][0]']
#
#  batch_normalization_32 (Ba  (None, 6, 6, 128)            384       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 6, 6, 128)            384       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 6, 6, 128)            0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 6, 6, 128)            0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  average_pooling2d_3 (Avera  (None, 6, 6, 768)            0         ['mixed3[0][0]']
#  gePooling2D)
#
#  conv2d_30 (Conv2D)          (None, 6, 6, 192)            147456    ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 6, 6, 192)            172032    ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 6, 6, 192)            172032    ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 6, 6, 192)            147456    ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (Ba  (None, 6, 6, 192)            576       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 6, 6, 192)            576       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 6, 6, 192)            576       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 6, 6, 192)            576       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 6, 6, 192)            0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 6, 6, 192)            0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 6, 6, 192)            0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 6, 6, 192)            0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 6, 6, 768)            0         ['activation_30[0][0]',
#                                                                      'activation_33[0][0]',
#                                                                      'activation_38[0][0]',
#                                                                      'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 6, 6, 160)            122880    ['mixed4[0][0]']
#
#  batch_normalization_44 (Ba  (None, 6, 6, 160)            480       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 6, 6, 160)            0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 6, 6, 160)            179200    ['activation_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 6, 6, 160)            480       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 6, 6, 160)            0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 6, 6, 160)            122880    ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 6, 6, 160)            179200    ['activation_45[0][0]']
#
#  batch_normalization_41 (Ba  (None, 6, 6, 160)            480       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 6, 6, 160)            480       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 6, 6, 160)            0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 6, 6, 160)            0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 6, 6, 160)            179200    ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 6, 6, 160)            179200    ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 6, 6, 160)            480       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 6, 6, 160)            480       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 6, 6, 160)            0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 6, 6, 160)            0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  average_pooling2d_4 (Avera  (None, 6, 6, 768)            0         ['mixed4[0][0]']
#  gePooling2D)
#
#  conv2d_40 (Conv2D)          (None, 6, 6, 192)            147456    ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 6, 6, 192)            215040    ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 6, 6, 192)            215040    ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 6, 6, 192)            147456    ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (Ba  (None, 6, 6, 192)            576       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 6, 6, 192)            576       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 6, 6, 192)            576       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 6, 6, 192)            576       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 6, 6, 192)            0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 6, 6, 192)            0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 6, 6, 192)            0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_49 (Activation)  (None, 6, 6, 192)            0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  mixed5 (Concatenate)        (None, 6, 6, 768)            0         ['activation_40[0][0]',
#                                                                      'activation_43[0][0]',
#                                                                      'activation_48[0][0]',
#                                                                      'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 6, 6, 160)            122880    ['mixed5[0][0]']
#
#  batch_normalization_54 (Ba  (None, 6, 6, 160)            480       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 6, 6, 160)            0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 6, 6, 160)            179200    ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 6, 6, 160)            480       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 6, 6, 160)            0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 6, 6, 160)            122880    ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 6, 6, 160)            179200    ['activation_55[0][0]']
#
#  batch_normalization_51 (Ba  (None, 6, 6, 160)            480       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_56 (Ba  (None, 6, 6, 160)            480       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 6, 6, 160)            0         ['batch_normalization_51[0][0]
# ...
#  conv2d_76 (Conv2D)          (None, 2, 2, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_78 (Ba  (None, 2, 2, 384)            1152      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  batch_normalization_79 (Ba  (None, 2, 2, 384)            1152      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 2, 2, 384)            1152      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  batch_normalization_83 (Ba  (None, 2, 2, 384)            1152      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  conv2d_84 (Conv2D)          (None, 2, 2, 192)            245760    ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (Ba  (None, 2, 2, 320)            960       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_78 (Activation)  (None, 2, 2, 384)            0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  activation_79 (Activation)  (None, 2, 2, 384)            0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  activation_82 (Activation)  (None, 2, 2, 384)            0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  activation_83 (Activation)  (None, 2, 2, 384)            0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  batch_normalization_84 (Ba  (None, 2, 2, 192)            576       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 2, 2, 320)            0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  mixed9_0 (Concatenate)      (None, 2, 2, 768)            0         ['activation_78[0][0]',
#                                                                      'activation_79[0][0]']
#
#  concatenate (Concatenate)   (None, 2, 2, 768)            0         ['activation_82[0][0]',
#                                                                      'activation_83[0][0]']
#
#  activation_84 (Activation)  (None, 2, 2, 192)            0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  mixed9 (Concatenate)        (None, 2, 2, 2048)           0         ['activation_76[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate[0][0]',
#                                                                      'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 2, 2, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_89 (Ba  (None, 2, 2, 448)            1344      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 2, 2, 448)            0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 2, 2, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 2, 2, 384)            1548288   ['activation_89[0][0]']
#
#  batch_normalization_86 (Ba  (None, 2, 2, 384)            1152      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 2, 2, 384)            1152      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 2, 2, 384)            0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 2, 2, 384)            0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 2, 2, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 2, 2, 384)            442368    ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 2, 2, 384)            442368    ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 2, 2, 384)            442368    ['activation_90[0][0]']
#
#  average_pooling2d_8 (Avera  (None, 2, 2, 2048)           0         ['mixed9[0][0]']
#  gePooling2D)
#
#  conv2d_85 (Conv2D)          (None, 2, 2, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_87 (Ba  (None, 2, 2, 384)            1152      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 2, 2, 384)            1152      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 2, 2, 384)            1152      ['conv2d_91[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 2, 2, 384)            1152      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  conv2d_93 (Conv2D)          (None, 2, 2, 192)            393216    ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (Ba  (None, 2, 2, 320)            960       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 2, 2, 384)            0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  activation_88 (Activation)  (None, 2, 2, 384)            0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 2, 2, 384)            0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  activation_92 (Activation)  (None, 2, 2, 384)            0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  batch_normalization_93 (Ba  (None, 2, 2, 192)            576       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 2, 2, 320)            0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  mixed9_1 (Concatenate)      (None, 2, 2, 768)            0         ['activation_87[0][0]',
#                                                                      'activation_88[0][0]']
#
#  concatenate_1 (Concatenate  (None, 2, 2, 768)            0         ['activation_91[0][0]',
#  )                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)  (None, 2, 2, 192)            0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  mixed10 (Concatenate)       (None, 2, 2, 2048)           0         ['activation_85[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'activation_93[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['mixed10[0][0]']
#  GlobalAveragePooling2D)
#
#  batch_normalization_94 (Ba  (None, 2048)                 8192      ['global_average_pooling2d[0][
#  tchNormalization)                                                  0]']
#
#  dropout (Dropout)           (None, 2048)                 0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  dense (Dense)               (None, 1024)                 2098176   ['dropout[0][0]']
#
#  batch_normalization_95 (Ba  (None, 1024)                 4096      ['dense[0][0]']
#  tchNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)                 0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  dense_1 (Dense)             (None, 1024)                 1049600   ['dropout_1[0][0]']
#
#  dense_2 (Dense)             (None, 124)                  127100    ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 25089948 (95.71 MB)
# Trainable params: 25049372 (95.56 MB)
# Non-trainable params: 40576 (158.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Plot Training & Validation Accuracy

# %%
plt.plot(history.history['acc'], color='blue', label='Training Accuracy')
plt.plot(history.history['val_acc'],
         color='red', label='Testing Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Plot Training and Validation Loss

# %%
plt.plot(history.history['loss'], color='blue', label='Training Loss')
plt.plot(history.history['val_loss'],
         color='red', label='Testing Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Plot Training and Testing Top 5 Accuracy

# %%
plt.plot(history.history['top_5_accuracy'],
         color='blue', label='Training Accuracy')
plt.plot(history.history['val_top_5_accuracy'],
         color='red', label='Testing Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
